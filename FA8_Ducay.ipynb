# %%
import pandas as pd

data = {'weight': [4.17, 5.58, 5.18, 6.11, 4.50, 4.61, 5.17, 4.53, 5.33, 5.14, 4.81, 4.17, 4.41, 3.59, 5.87, 3.83, 6.03, 4.89, 4.32, 4.69, 6.31, 5.12, 5.54, 5.50, 5.37, 5.29, 4.92, 6.15, 5.80, 5.26],
        'group': ['ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2']}

df = pd.DataFrame(data)

display(df)
# Out:
#     weight group
# 0     4.17  ctrl
# 1     5.58  ctrl
# 2     5.18  ctrl
# 3     6.11  ctrl
# 4     4.50  ctrl
# 5     4.61  ctrl
# 6     5.17  ctrl
# 7     4.53  ctrl
# 8     5.33  ctrl
# 9     5.14  ctrl
# 10    4.81  trt1
# 11    4.17  trt1
# 12    4.41  trt1
# 13    3.59  trt1
# 14    5.87  trt1
# 15    3.83  trt1
# 16    6.03  trt1
# 17    4.89  trt1
# 18    4.32  trt1
# 19    4.69  trt1
# 20    6.31  trt2
# 21    5.12  trt2
# 22    5.54  trt2
# 23    5.50  trt2
# 24    5.37  trt2
# 25    5.29  trt2
# 26    4.92  trt2
# 27    6.15  trt2
# 28    5.80  trt2
# 29    5.26  trt2

# %% [markdown]
# ## Assumption #1: You have one dependent variable that is measured at the continuous level.
# ## Assumption #2: You have one independent variable that consists of three or more categorical, independent groups.
# ## Assumption #3: You should have independence of observations, which means that there is no relationship between the observations in each group of the independent variable or among the groups themselves.

# %%
import pandas as pd

data = {'weight': [4.17, 5.58, 5.18, 6.11, 4.50, 4.61, 5.17, 4.53, 5.33, 5.14, 4.81, 4.17, 4.41, 3.59, 5.87, 3.83, 6.03, 4.89, 4.32, 4.69, 6.31, 5.12, 5.54, 5.50, 5.37, 5.29, 4.92, 6.15, 5.80, 5.26],
        'group': ['ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2']}

df = pd.DataFrame(data)

ctrl = pd.DataFrame(df[df['group'] == 'ctrl'])
trt1 = pd.DataFrame(df[df['group'] == 'trt1'])
trt2 = pd.DataFrame(df[df['group'] == 'trt2'])

print("Control group:")
display(ctrl)

print("Treatment group 1:")
display(trt1)

print("Treatment group 2:")
display(trt2)
# Out:
# Control group:
#    weight group
# 0    4.17  ctrl
# 1    5.58  ctrl
# 2    5.18  ctrl
# 3    6.11  ctrl
# 4    4.50  ctrl
# 5    4.61  ctrl
# 6    5.17  ctrl
# 7    4.53  ctrl
# 8    5.33  ctrl
# 9    5.14  ctrl
# Treatment group 1:
#     weight group
# 10    4.81  trt1
# 11    4.17  trt1
# 12    4.41  trt1
# 13    3.59  trt1
# 14    5.87  trt1
# 15    3.83  trt1
# 16    6.03  trt1
# 17    4.89  trt1
# 18    4.32  trt1
# 19    4.69  trt1
# Treatment group 2:
#     weight group
# 20    6.31  trt2
# 21    5.12  trt2
# 22    5.54  trt2
# 23    5.50  trt2
# 24    5.37  trt2
# 25    5.29  trt2
# 26    4.92  trt2
# 27    6.15  trt2
# 28    5.80  trt2
# 29    5.26  trt2

# %%
ctrl = pd.DataFrame(df[df['group'] == 'ctrl'])
trt1 = pd.DataFrame(df[df['group'] == 'trt1'])
trt2 = pd.DataFrame(df[df['group'] == 'trt2'])

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
g = sns.catplot(x="group", y="weight", kind="violin", inner=None, data=ctrl)
sns.swarmplot(x="group", y="weight", color="k", size=3, data=ctrl, ax=g.ax)
plt.title("Raincloud plot of PlantGrowth dataset")
plt.show()

sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
g = sns.catplot(x="group", y="weight", kind="violin", inner=None, data=trt1)
sns.swarmplot(x="group", y="weight", color="k", size=3, data=trt1, ax=g.ax)
plt.title("Raincloud plot of PlantGrowth dataset")
plt.show()

sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
g = sns.catplot(x="group", y="weight", kind="violin", inner=None, data=trt2)
sns.swarmplot(x="group", y="weight", color="k", size=3, data=trt2, ax=g.ax)
plt.title("Raincloud plot of PlantGrowth dataset")
plt.show()

# %%
import pandas as pd
import numpy as np

# Load the PlantGrowth dataset
data = {'weight': [4.17, 5.58, 5.18, 6.11, 4.50, 4.61, 5.17, 4.53, 5.33, 5.14, 4.81, 4.17, 4.41, 3.59, 5.87, 3.83, 6.03, 4.89, 4.32, 4.69, 6.31, 5.12, 5.54, 5.50, 5.37, 5.29, 4.92, 6.15, 5.80, 5.26],
        'group': ['ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'ctrl', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt1', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2', 'trt2']}
df = pd.DataFrame(data)

# Calculate the z-score for each value within each group
z_scores = df.groupby('group')['weight'].transform(lambda x: np.abs((x - x.mean()) / x.std()))

# Identify the outliers
outliers = df[z_scores > 3]

# Print the outliers for each group
for group in df['group'].unique():
    print(f"Outliers for {group}:")
    print(outliers[outliers['group'] == group])
# Out:
# Outliers for ctrl:
# Empty DataFrame
# Columns: [weight, group]
# Index: []
# Outliers for trt1:
# Empty DataFrame
# Columns: [weight, group]
# Index: []
# Outliers for trt2:
# Empty DataFrame
# Columns: [weight, group]
# Index: []

# %% [markdown]
# ### There are no Outliers

# %% [markdown]
# ## Assumption #5: Your dependent variable should be approximately normally distributed for each group of the independent variable.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy.stats import shapiro, levene, ttest_ind

ctrl = df[df['group'] == 'ctrl']['weight']
trt1 = df[df['group'] == 'trt1']['weight']
trt2 = df[df['group'] == 'trt2']['weight']

ctrl_normality = shapiro(ctrl)
trt1_normality = shapiro(trt1)
trt2_normality = shapiro(trt2)

ctrl_normality, trt1_normality, trt2_normality
# Out:
# (ShapiroResult(statistic=0.9566815495491028, pvalue=0.7474744915962219),
#  ShapiroResult(statistic=0.9304108619689941, pvalue=0.451945960521698),
#  ShapiroResult(statistic=0.941005289554596, pvalue=0.5642533898353577))

# %% [markdown]
# ### p values > 0.05 therefore normally distributed

# %% [markdown]
# ## Assumption #6: You have homogeneity of variances (i.e., the variance of the dependent variable is equal in each group of your independent variable).

# %%
equal_variances_test = levene(ctrl, trt1, ctrl_trt2)
equal_variances_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9504\2073029708.py in <module>
# ----> 1 equal_variances_test = levene(ctrl, trt1, ctrl_trt2)
#       2 equal_variances_test
#
# NameError: name 'ctrl_trt2' is not defined

# %% [markdown]
# In the context of Levene's test, a high p-value (such as 0.43473696918517934) suggests that the variances of the dependent variable are not significantly different across the groups defined by your independent variable. This result implies that the assumption of homogeneity of variances is met.

# %%
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import pandas as pd


tukey_result = pairwise_tukeyhsd(endog=df['weight'], groups=df['group'], alpha=0.05)
print(tukey_result)

# %% [markdown]
# All assumptions were satisfied.
#
# Based on the results from the Tukey HSD test you provided, there is one statistically significant mean difference observed, which is between the 'trt1' and 'trt2' groups.Between 'trt1' and 'trt2'.
#
# Mean Difference: 0.865
# p-value: 0.012 (significant at the 0.05 level)
#
# Interpretation: The mean of the dependent variable in 'trt2' is significantly higher than in 'trt1' by 0.865 units. This can be interpreted as a statistically significant mean increase when moving from 'trt1' to 'trt2'.
# For the other comparisons ('ctrl' vs. 'trt1' and 'ctrl' vs. 'trt2'), the differences are not statistically significant. Thus, we cannot conclusively say there was a significant mean increase or decrease in these cases.
#
# In summary, the only statistically significant mean increase observed is in the comparison between 'trt1' and 'trt2'.
